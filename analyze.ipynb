# %%
from wifidebug import Plotter, PingDatabase, main

db = PingDatabase()

plotter = Plotter(db)

# %%
test_ip = "10.0.2.51"
main(test_ip, 1000, True)
# Out:
# Will ping 10.0.2.51 every 1000 milliseconds
#
# Closing connection...

# %%
plotter.plot_pings(test_ip)
